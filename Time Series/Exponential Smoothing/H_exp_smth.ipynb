# %% [markdown]
# Implementation of Load Forecasting using **Moving Average** and **Exponential Smoothing** Methods on **Hourly Data**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b8115d1-911d-481f-a5af-0061cd0f67c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b8115d1-911d-481f-a5af-0061cd0f67c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving H_load.csv to H_load.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['H_load.csv']))
plt.figure(figsize=(20,5))
plt.plot(df[:500], label='Load')
plt.legend(loc='upper left')
plt.xlabel("Hours")
plt.ylabel("Load")
plt.show()

# %%
def exp_smth (l,a,n=-1):
    if n<=0:
      return l[0]
    
    if (a==1):
      return l[n-1]

    
   # Y=aXt+(1-a)Yt-1, 0<a<1
    return a*l[n-1]+(1-a)*exp_smth(l,a,n-1)

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
l=list(df['Load']) #converting into a list


l_exp_smth=[]
for n in range(len(l)):
  l_exp_smth.append(exp_smth(l,1,n))  #assigning previous value

# %%
plt.figure(figsize=(10,6))
plt.plot(l[0:100], label='Actual_LoadLoad')
plt.plot(l_exp_smth[0:100], label='Predicted_Load', color='Red')
plt.legend(loc='upper left')
plt.xlabel("hours")
plt.ylabel("Load")
plt.title("Actual Load vs Predicted Load")
plt.show()

# %%
mape=mean_absolute_percentage_error(l, l_exp_smth)
print("Mean Absolute Error Percentage in Moving Average Method is ", round(mape,2),"%")
# Out:
# Mean Absolute Error Percentage in Moving Average Method is  7.28 %
